# %% [markdown]
# ## Analisis Exploratorio
# Autor: Nicol Huaraca

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("winequality-red.csv")
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# ## Matriz de Correlación

# %%
nombres = ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide',
           'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol', 'quality']

mask = np.zeros_like(df[nombres].corr(), dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

f, ax = plt.subplots(figsize=(12, 9))
# plt.title('Matriz de Correlación de Pearson',fontsize=20)

sns.heatmap(df[nombres].corr(),linewidths=0.25, vmax=1.0, square=True, cmap="Blues",
            linecolor='w', annot=True, mask=mask, cbar_kws={"shrink": .75}, fmt= '.2f')
f.tight_layout()
plt.savefig('p1_1.png')

# %% [markdown]
# ## Box PLot

# %%
most = ['alcohol', 'sulphates', 'volatile acidity', 'citric acid']

f2, ax = plt.subplots(2, 2, figsize=(16, 12))
sns.boxplot('quality', 'alcohol', data=df, ax=ax[0, 0], palette='Blues')
sns.boxplot('quality', 'sulphates', data=df, ax=ax[0, 1], palette='Blues')
sns.boxplot('quality', 'volatile acidity', data=df, ax=ax[1, 0], palette='Blues')
sns.boxplot('quality', 'citric acid', data=df, ax=ax[1, 1], palette='Blues')
plt.savefig('p1_2.png')

# %% [markdown]
# ## Histogramas

# %%
# Frecuencias para calidad
sns.countplot(x='quality', data=df)
plt.savefig('p1_3.png')

# %%
df['quality'].hist()
# Out:
# <AxesSubplot:>
